# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("raw_sales.csv",parse_dates=['datesold'])

# %%
df.head()
# Out:
#     datesold  postcode   price propertyType  bedrooms
# 0 2007-02-07      2607  525000        house         4
# 1 2007-02-27      2906  290000        house         3
# 2 2007-03-07      2905  328000        house         3
# 3 2007-03-09      2905  380000        house         4
# 4 2007-03-21      2906  310000        house         3

# %%
df.tail()
# Out:
#         datesold  postcode   price propertyType  bedrooms
# 29575 2019-07-25      2900  500000         unit         3
# 29576 2019-07-25      2612  560000         unit         2
# 29577 2019-07-26      2912  464950         unit         2
# 29578 2019-07-26      2601  589000         unit         2
# 29579 2019-07-26      2612  775000         unit         2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  datetime64[ns]
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                             datesold      postcode         price      bedrooms
# count                          29580  29580.000000  2.958000e+04  29580.000000
# mean   2015-02-21 07:35:42.474645248   2730.249730  6.097363e+05      3.250169
# min              2007-02-07 00:00:00   2600.000000  5.650000e+04      0.000000
# 25%              2013-02-05 00:00:00   2607.000000  4.400000e+05      3.000000
# 50%              2015-09-30 00:00:00   2615.000000  5.500000e+05      3.000000
# 75%              2017-07-26 00:00:00   2905.000000  7.050000e+05      4.000000
# max              2019-07-27 00:00:00   2914.000000  8.000000e+06      5.000000
# std                              NaN    146.717292  2.817079e+05      0.951275

# %%
df1=df[df['datesold'].dt.year==2012]
df1.head()
# Out:
#        datesold  postcode   price propertyType  bedrooms
# 4770 2012-01-03      2615  456000        house         3
# 4771 2012-01-03      2913  715000        house         4
# 4772 2012-01-04      2905  560000        house         4
# 4773 2012-01-05      2913  425000        house         3
# 4774 2012-01-05      2904  522500        house         3

# %%
df2=df.drop('propertyType',axis=1)
df2=df2.groupby(df['datesold'].dt.year).mean()

# %%
df2.head()
# Out:
#                               datesold     postcode          price  bedrooms
# datesold
# 2007     2007-09-17 18:56:19.591836672  2737.292517  522377.210884  3.292517
# 2008     2008-09-17 06:43:22.816901376  2734.707355  493814.162754  3.333333
# 2009     2009-07-01 19:28:21.542777088  2745.084853  496092.032959  3.279102
# 2010     2010-07-18 15:52:54.019292672  2744.045659  559564.810289  3.325402
# 2011     2011-07-03 19:45:09.369259008  2738.410900  566715.110227  3.292713

# %%
plt.plot(df2['datesold'],df2['price'])

# %%
df2=df.groupby(df['datesold'].dt.year).size()

# %%
df2.head()
# Out:
# datesold
# 2007     147
# 2008     639
# 2009    1426
# 2010    1555
# 2011    1633
# dtype: int64

# %%
plt.plot(df2)

# %%
df.head()
# Out:
#     datesold  postcode   price propertyType  bedrooms
# 0 2007-02-07      2607  525000        house         4
# 1 2007-02-27      2906  290000        house         3
# 2 2007-03-07      2905  328000        house         3
# 3 2007-03-09      2905  380000        house         4
# 4 2007-03-21      2906  310000        house         3

# %%
df['Count']=1

# %%
df
# Out:
#         datesold  postcode   price propertyType  bedrooms  Count
# 0     2007-02-07      2607  525000        house         4      1
# 1     2007-02-27      2906  290000        house         3      1
# 2     2007-03-07      2905  328000        house         3      1
# 3     2007-03-09      2905  380000        house         4      1
# 4     2007-03-21      2906  310000        house         3      1
# ...          ...       ...     ...          ...       ...    ...
# 29575 2019-07-25      2900  500000         unit         3      1
# 29576 2019-07-25      2612  560000         unit         2      1
# 29577 2019-07-26      2912  464950         unit         2      1
# 29578 2019-07-26      2601  589000         unit         2      1
# 29579 2019-07-26      2612  775000         unit         2      1
#
# [29580 rows x 6 columns]

# %%
df.loc['2010-01-01':'2015-12-01']
# Out:
#         datesold  postcode    price propertyType  bedrooms  Count
# 20100 2017-11-14      2913   865000        house         4      1
# 20101 2017-11-14      2605  1000000        house         5      1
# 20102 2017-11-14      2605  1300000        house         5      1
# 20103 2017-11-15      2913   450000        house         3      1
# 20104 2017-11-15      2906   465000        house         3      1
# 20105 2017-11-15      2906   477000        house         3      1
# 20106 2017-11-15      2906   510000        house         3      1
# 20107 2017-11-15      2604   515000        house         1      1
# 20108 2017-11-15      2612   530000        house         2      1
# 20109 2017-11-15      2617   530000        house         3      1
# 20110 2017-11-15      2902   540000        house         3      1
# 20111 2017-11-15      2615   590000        house         3      1
# 20112 2017-11-15      2904   597500        house         4      1
# ...

# %%
df.drop('propertyType',axis=1)
# Out:
#         datesold  postcode   price  bedrooms  Count
# 0     2007-02-07      2607  525000         4      1
# 1     2007-02-27      2906  290000         3      1
# 2     2007-03-07      2905  328000         3      1
# 3     2007-03-09      2905  380000         4      1
# 4     2007-03-21      2906  310000         3      1
# ...          ...       ...     ...       ...    ...
# 29575 2019-07-25      2900  500000         3      1
# 29576 2019-07-25      2612  560000         2      1
# 29577 2019-07-26      2912  464950         2      1
# 29578 2019-07-26      2601  589000         2      1
# 29579 2019-07-26      2612  775000         2      1
#
# [29580 rows x 5 columns]

# %%
df4=df['price'].groupby(by=[df['datesold'].dt.month,df['datesold'].dt.year]).mean()

# %%
df4
# Out:
# datesold  datesold
# 1         2008        504428.571429
#           2009        482238.640449
#           2010        546984.615385
#           2011        508140.609756
#           2012        541473.033708
#                           ...
# 12        2014        589241.845018
#           2015        636504.133333
#           2016        654594.182825
#           2017        697552.703125
#           2018        674591.105023
# Name: price, Length: 150, dtype: float64

# %%
df4.plot()
# Out:
# <Axes: xlabel='datesold,datesold'>

# %%
plt.hist(df['bedrooms'])
# Out:
# (array([   30.,     0.,  1627.,     0.,  3598.,     0., 11933.,     0.,
#         10442.,  1950.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df['price']=df['price'].astype(int)

# %%
df[df['price']>500000]
# Out:
#         datesold  postcode    price propertyType  bedrooms  Count
# 0     2007-02-07      2607   525000        house         4      1
# 7     2007-04-30      2606  1530000        house         4      1
# 12    2007-06-27      2612   850000        house         4      1
# 13    2007-06-28      2904   765000        house         4      1
# 14    2007-06-30      2615   517000        house         4      1
# ...          ...       ...      ...          ...       ...    ...
# 29567 2019-07-23      2912   549950         unit         3      1
# 29569 2019-07-24      2601   590000         unit         1      1
# 29576 2019-07-25      2612   560000         unit         2      1
# 29578 2019-07-26      2601   589000         unit         2      1
# 29579 2019-07-26      2612   775000         unit         2      1
#
# [17873 rows x 6 columns]

# %%
plt.plot(df2,marker='o')

# %%
df4=df['price'].groupby(by=[df['datesold'].dt.year,df['datesold'].dt.month]).mean()

# %%
df4
# Out:
# datesold  datesold
# 2007      2           407500.000000
#           3           339333.333333
#           4           798000.000000
#           5           339500.000000
#           6           520333.333333
#                           ...
# 2019      3           651666.737288
#           4           655325.561321
#           5           641491.136364
#           6           703275.396825
#           7           583192.056000
# Name: price, Length: 150, dtype: float64
